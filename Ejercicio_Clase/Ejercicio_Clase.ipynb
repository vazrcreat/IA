# %% [markdown]
# # Ejercicio Clase
#
# 1. En un documento de word, colocar la liga de un repositorio con la resolución de los ejercicios.
#    (recuerde anexar el ID del commit en el documento de word)
#
# 2. Dado el dataset de wh2018 (2018.csv) haga una análisis de correlaciones entre las variables numéricas continuas, en      markdown haga por lo menos 4 conclusiones de los comportamientos que haya encontrado.
#
# 3. En otro comando de markdown ponga 3 ejemplos de causalidad.

# %% [markdown]
# Importando librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Leyendo el archivo csv

# %%
wh2018=pd.read_csv('2018.csv')
wh2018
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.632           1.305
# 1               2                    Norway  7.594           1.456
# 2               3                   Denmark  7.555           1.351
# 3               4                   Iceland  7.495           1.343
# 4               5               Switzerland  7.487           1.420
# ..            ...                       ...    ...             ...
# 151           152                     Yemen  3.355           0.442
# 152           153                  Tanzania  3.303           0.455
# 153           154               South Sudan  3.254           0.337
# 154           155  Central African Republic  3.083           0.024
# 155           156                   Burundi  2.905           0.091
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# 0             1.592                    0.874                         0.681
# ...

# %% [markdown]
# Pasos para obtener correlacion

# %%
wh2018.columns
columns_to_use=['Score', 'GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']
corr_use=wh2018.loc[ : , columns_to_use].corr()
corr_use
# Out:
#                                  Score  GDP per capita  Social support  \
# Score                         1.000000        0.802124        0.745760
# GDP per capita                0.802124        1.000000        0.672080
# Social support                0.745760        0.672080        1.000000
# Healthy life expectancy       0.775814        0.844273        0.667288
# Freedom to make life choices  0.544280        0.332275        0.411087
# Generosity                    0.135825       -0.011241        0.018226
# Perceptions of corruption     0.405292        0.319582        0.218364
#
#                               Healthy life expectancy  \
# Score                                        0.775814
# GDP per capita                               0.844273
# Social support                               0.667288
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.355475
# Generosity                                   0.020751
# ...

# %% [markdown]
# Generando Grafica

# %%
f, ax=plt.subplots(figsize=(10,8))
sns.heatmap(corr_use, mask=np.zeros_like(corr_use, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True, ax=ax )
# Out:
# C:\Users\usuario\AppData\Local\Temp/ipykernel_13108/2940125105.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr_use, mask=np.zeros_like(corr_use, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True, ax=ax )
# <AxesSubplot:>

# %% [markdown]
# Conclusiones:
# 1.los indices de generosidad no tienen ningun tipo de ingerencia en la calidad de vida o la espectativa de vida saludable
# 2.la corrupcion influye enormemente en la expectativa de vida en un pais  afectando asi todas las clases  de la sociedad
# 3.entre mas alto  es el pib de un pais se podria decir que tiene mas probabilidades detener una vida mejor al tener mejores oportinidades con un salario mejor
# 4.la libre expresion o libertad de desiciones influye y ala vez no influye en la calidad de vida esto se podria conciderar de manera individual a las personas

# %% [markdown]
# Ejemplos Causalidades
#
# 1. Velocidad del ventilador: la velocidad del ventilador depende de la entrada actual (ya sea de 1, 2, 3, 4, 5) o de la entrada anterior (velocidad que se configuró previamente).
# 2. Conversación con una persona al azar: su respuesta depende de los argumentos actuales y anteriores de la otra persona.
# 3. Enojarse por que alguien olvido realizar una tarea en una fecha en especifico. La persona lo olvidó, por lo tanto, causó el enojo. Pero, en realidad la molestia es porque se interpreto su olvido como una falta de preocupación. Por lo tanto se esta molesto por mi propia interpretación de por qué lo olvidó, no por la verdadera razón de porque no realizo la tarea.
